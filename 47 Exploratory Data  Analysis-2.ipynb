# %% [markdown]
# # Exploratory Data nalysis-2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# ## Flight Price:

# %% [markdown]
# ### Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df = pd.read_excel('flight_price.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# **Observation:**
# - Flight dataset have 11 Columns and 10683 Rows

# %% [markdown]
# ### Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
sns.histplot(df['Price'], kde = True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# **Observation:**
# - As we can see that our distribution for price of the flight ticket is Right skewed.

# %% [markdown]
# ### Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# **Observation:**
# - Our price range for the flight ticket is between 1759 to 79512.
# - Our  minimum price for the flight ticket is 1759.
# - Our  maximum price for the flight ticket is 79512.

# %% [markdown]
# ### Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
sns.boxplot(x = df['Airline'], y = df['Price'])
plt.xticks(rotation=90)
plt.xlabel('Airline')
plt.ylabel('Price')
plt.title('Price of Flights vary by Airline')
# Out:
# Text(0.5, 1.0, 'Price of Flights vary by Airline')

# %% [markdown]
# ### Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
sns.boxplot(data = df)
plt.xticks(rotation=90)
plt.xlabel('Airline')
plt.ylabel('Price')
plt.title('Price of Flights vary by Airline')
# Out:
# Text(0.5, 1.0, 'Price of Flights vary by Airline')

# %% [markdown]
# **observation**
# - we have so many outliers in Price column
# **Conclusion**
# - As we can see we have too many outliers in our data set in Price column so we need to handle it , if we not do so it will affect in our analysis , it may give wrong or biased predictions.

# %% [markdown]
# ### Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# **Obsevation**
# - To identify the peak travel season from the Flight Price dataset, I would analyze the following features:
#
# 1. Month of the year: I would analyze the number of flights and the average price of flights for each month of the year. This would help me identify the months with the highest demand and the corresponding peak prices.
#
# 2. Departure and arrival locations: I would analyze the number of flights and the average price of flights for each departure and arrival location. This would help me identify the most popular travel destinations and the corresponding peak travel seasons.
#
# 3. Day of the week: I would analyze the number of flights and the average price of flights for each day of the week. This would help me identify the days with the highest demand and the corresponding peak prices.
#
# 4. Holiday periods: I would also consider the holiday periods for different cities and regions. This would help me identify the peak travel seasons for holidays such as Christmas, Holi, Winter Vacations, Dipawali and summer vacations etc.
#
# - To present my findings to my boss, I would create visualizations such as line charts, bar charts, and heat maps to showcase the trends and patterns in the data. I would provide a summary of my analysis and highlight the key findings such as the peak travel seasons for different locations and the factors driving the high demand and prices.

# %% [markdown]
# ### Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %% [markdown]
# **Observation**
# - As a data analyst for a flight booking website, some of the key features that I would analyze in the Flight Price dataset to identify any trends in flight prices are:
#
# 1. Time-related features: I would analyze features such as the departure time, arrival time, and duration of the flight. These features can give insights into how the time of the day, day of the week, and season affect the flight prices.
#
# 2. Route-related features: I would analyze features such as the origin and destination airports, the distance between them, and the number of stops or layovers in the route. These features can provide insights into how the demand and supply of flights on specific routes impact the flight prices.
#
# 3. Airline-related features: I would analyze features such as the airline name, the type of aircraft used, and the class of service. These features can provide insights into how the different airlines and service levels affect the flight prices.
#
# - To present my findings to the team, I would use a combination of visualizations such as:
#
# 1. Line charts: to show how the flight prices change over time, by day of the week, or by season.
#
# 2. Scatterplots: to show the relationship between the flight prices and the distance, number of stops, and duration of the flights.
#
# 3. Bar charts: to compare the average flight prices across different airlines, routes, and classes of service.
#
# 4. Heatmaps: to show the demand and supply of flights on specific routes and how they impact the flight prices.
#
# 5. Box plots: to show the distribution of flight prices across different customer demographics and travel purposes.

# %% [markdown]
# ### Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %% [markdown]
# **Observations**
# - As a data scientist, I would analyze the Flight Price dataset to identify the factors that affect flight prices. Here are some features that I would consider analyzing:
#
# 1. Departure and Arrival Cities: The distance between the departure and arrival cities can have a significant impact on the flight price.
#
# 2. Flight Duration: The longer the flight duration, the higher the flight price is likely to be.
#
# 3. Departure and Arrival Times: The time of day or day of the week that a flight departs or arrives can affect the flight price.
#
# 4. Airline: Different airlines have different pricing strategies and may charge different prices for the same flight.
#
# 5. Travel Class: First class, business class, and economy class tickets will have different price points.(this feature is not included in our dataset but it may have very good correlation .)
#
# 6. Number of Stops: Non-stop flights are generally more expensive than flights with layovers.
#
# 7. Seasonality: The time of year can impact flight prices, with peak travel times (such as holidays and summer vacation) being more expensive.
#
# - Once I have identified the factors that affect flight prices, I would present my findings to the management team in a clear and concise manner. I would use data visualizations such as graphs and charts to illustrate the relationships between flight prices and the factors analyzed. I would also provide statistical analysis to support my findings and highlight any key insights.

# %% [markdown]
# ## Google Playstore:

# %% [markdown]
# ### Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# **Observation:**
#
# - Google Playstore dataset have 13 Columns and 10841 Rows

# %% [markdown]
# ### Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
plt.figure(figsize=(18, 7))
sns.boxplot(x = df1['Category'], y = df1['Rating'])
plt.xticks(rotation=90)
plt.ylim(0.5, 5.5)
plt.title('Rating of Apps in Playstore vary by Category')
# Out:
# Text(0.5, 1.0, 'Rating of Apps in Playstore vary by Category')

# %% [markdown]
# ### Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
## Missing value
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# **Observation**
# - We can simply drop those rows which have Nan value with respect to columns ['Type', 'Content Rating', 'Current Ver', 'Android ver'] or we can use variour imputation methods.
# - In case of Rating column we can not simply drop all the rows which have Nan value in RAting column. So, here we need to use imputation methods.

# %% [markdown]
# ### Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
df1.drop([10472], axis = 0, inplace = True)
## droping this particular row because it has '1000+' type of value in size column.

# %%
df1['Size'] = df1['Size'].str.replace('M', '000')
df1['Size'] = df1['Size'].str.replace('k', '')
df1['Size'] = df1['Size'].replace('Varies with device', np.nan)
df1['Size'] = df1['Size'].astype(float)

# %%
sns.scatterplot(x = df1['Rating'], y = df1['Size'])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Size'>

# %% [markdown]
# ### Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
Price = []
for i in df1['Price']:
    Price.append(i.replace("$", ''))
    
df1['Price'] = Price
df1['Price'] = df1['Price'].astype('float')

# %%
df1.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size              float64
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
plt.figure(figsize=(18, 7))
sns.barplot(x = df1['Category'], y = df1['Price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
frequency = df1.groupby('App')['Installs'].sum().reset_index()
frequency = frequency.sort_values('Installs', ascending=False)

# %%
frequency.head(10)
# Out:
#                                               App  \
# 2364                             Candy Crush Saga
# 8303                                 Temple Run 2
# 8815                              Viber Messenger
# 7889                                     Snapchat
# 7115                                          Pou
# 9507                imo free video calls and chat
# 3480                                      Dropbox
# 5672                  LINE: Free Calls & Messages
# 4920                              Google Calendar
# 8672  UC Browser - Fast Download Private & Secure
#
#                                                Installs
# 2364  500,000,000+500,000,000+500,000,000+500,000,00...
# 8303  500,000,000+500,000,000+500,000,000+500,000,00...
# 8815  500,000,000+500,000,000+500,000,000+500,000,00...
# 7889   500,000,000+500,000,000+500,000,000+500,000,000+
# 7115   500,000,000+500,000,000+500,000,000+500,000,000+
# 9507   500,000,000+500,000,000+500,000,000+500,000,000+
# ...

# %% [markdown]
# ### Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %% [markdown]
# To analyze the Google Playstore dataset and identify the most popular app categories, I would approach the task by following these steps:
#
# 1. Data collection: Collect the relevant data from the Google Playstore dataset, which includes app name, category, rating, reviews, installs, size, price, and other relevant features.
#
# 2. Data cleaning: Remove any duplicate entries, missing or invalid values, and irrelevant data. Also, convert the necessary fields into the required data types.
#
# 3. Data analysis: Analyze the cleaned data to identify the most popular app categories. The analysis could involve the following features:
#
# - Category: Identify the number of apps in each category and their respective percentages in the dataset.
# - Installs: Identify the number of installs for each app and category and their respective percentages.
# - Ratings: Identify the average ratings for each app and category and their respective percentages.
# - Reviews: Identify the number of reviews for each app and category and their respective percentages.
# - Price: Identify the pricing strategy for each app and category and their respective percentages.
#
# 4.  Visualization: Use graphs and charts to present the analyzed data visually. This will help in identifying the most popular app categories and understanding the relationship between various features.
#
# 5. Recommendations: Based on the analysis, recommend the most popular app categories to the company for launching their new app on the Google Playstore. Additionally, suggest the app features that could help them stand out in the identified categories.

# %% [markdown]
# ### Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %% [markdown]
# To identify the most successful app developers on Google Playstore, the following features can be analyzed:
#
# 1. Number of downloads: This feature shows the popularity of the app developed by the developer.
#
# 2. User rating: It indicates the satisfaction level of the users with the app developed by the developer.
#
#
# 3. Number of reviews: This feature shows the engagement level of users with the app developed by the developer.
#
# 4. App size: It represents the size of the app, which is an essential feature as users tend to download smaller size apps more often.
#
# 5. Category: It represents the genre of the app developed by the developer.
#
# To present these findings, the following data visualizations can be used:
#
# 1. Scatter plot: It can be used to visualize the correlation between the number of downloads and user ratings, revenue, and the number of reviews. This plot can help to identify the most successful app developers based on their popularity, user satisfaction, and engagement level.
#
# 2. Bar chart: It can be used to visualize the revenue generated by the app developers. This chart can help to identify the app developers who have earned the most revenue.
#
# 3. Heat map: It can be used to visualize the correlation between the app size, category, and user rating. This plot can help to identify the app developers who have developed smaller size apps with higher user ratings.

# %% [markdown]
# ### Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %% [markdown]
# To determine the best time to launch a new app on the Google Play Store, the marketing research firm should analyze the following features:
#
# 1. Category: Analyzing the most popular app categories and their trends can help the company identify the categories that are in high demand and plan the launch accordingly.
#
# 2. Ratings: Looking at the average ratings of the top apps can help the company understand user preferences and the quality of the apps available in the market.
#
# 3. Reviews: Analyzing the number of reviews and the sentiment analysis of the reviews can help the company understand user feedback and expectations.
#
# 4. Price: Looking at the pricing trends of the top apps can help the company determine the optimal price range for their new app.
#
# 5. Installs: Analyzing the number of installs of the top apps can help the company understand user behavior and preferences in terms of the app's popularity..
#
# To present these findings, the marketing research firm can use various data visualizations such as:
#
# - A bar chart or a pie chart to display the distribution of app categories and their popularity.
#
# - A scatter plot to show the relationship between app ratings and installs.
#
# - A line chart to display the trend in the number of app reviews and sentiment analysis.
#
# - A histogram or a box plot to show the distribution of app prices.
#
# - A line chart or a heatmap to display the seasonal trends in app launches.
